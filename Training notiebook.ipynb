# %%
import urllib.request
import os
import zipfile
import random
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import layers
from tensorflow.keras import Model
import tensorflow as tf
from shutil import copyfile
import pandas as pd

# %%
tf.random.set_seed(1)

# %% [markdown]
# # Loading data

# %%
IMAGE_TEST_DIR = "/kaggle/input/sign-classification/test"
IMAGE_TRAIN_DIR = "/kaggle/input/sign-classification/final_data/final_data"
train_label_file= '/kaggle/input/sign-classification/Train.csv'
test_label_file = '/kaggle/input/sign-classification/Test.csv'

# %%
df_train = pd.read_csv(train_label_file)
df_test = pd.read_csv(test_label_file)

# %%
print("Number of training images", df_train.shape[0])
print("Number of testing images", df_test.shape[0])
# Out:
# Number of training images 6249
# Number of testing images 2679

# %%
df_train.columns
# Out:
# Index(['img_IDS', 'Label'], dtype='object')

# %%
df_train["Label"].unique()
# Out:
# array(['Temple', 'Church', 'Enough/Satisfied', 'Me', 'Love', 'Mosque',
#        'You', 'Friend', 'Seat'], dtype=object)

# %%
print(df_train["Label"].nunique())
# Out:
# 9

# %% [markdown]
# # Process Dataset

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
      rotation_range=40,
      width_shift_range=0.1,
      height_shift_range=0.1,
      brightness_range=[0.2,1.0],
      shear_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest',
      validation_split=0.2 )

train_generator = train_datagen.flow_from_directory(IMAGE_TRAIN_DIR,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224,224),
                                                    shuffle=True)


validation_generator = train_datagen.flow_from_directory(IMAGE_TRAIN_DIR,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(224,224),
                                                    shuffle=True,
                                                    subset="validation",
                                                    )
# Out:
# Found 6249 images belonging to 9 classes.
# Found 1245 images belonging to 9 classes.

# %%
def preprocess_image_input(input_images):
    input_images = input_images.astype('float32')
    output_ims = tf.keras.applications.resnet50.preprocess_input(input_images)
    return output_ims

# %%
def feature_extractor(inputs):

    feature_extractor = tf.keras.applications.resnet.ResNet50(input_shape=(224, 224,3),
                                               include_top=False,
                                               weights='imagenet')(inputs)
    return feature_extractor



def classifier(inputs):
    x = tf.keras.layers.GlobalAveragePooling2D()(inputs)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(256, activation="relu")(x)
    x = tf.keras.layers.Dense(128, activation="relu")(x)

    x = tf.keras.layers.Dense(9, activation="softmax", name="classification")(x)
    return x


def final_model(inputs):


    resnet_feature_extractor = feature_extractor(inputs)
    classification_output = classifier(resnet_feature_extractor)

    return classification_output


def define_compile_model():
    inputs = tf.keras.layers.Input(shape=(224,224,3))
  
    classification_output = final_model(inputs) 
    model = tf.keras.Model(inputs=inputs, outputs = classification_output)
 
  # compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss= tf.keras.losses.CategoricalCrossentropy() ,
              metrics=['acc'])

    return model


model = define_compile_model()

model.summary()
# Out:
# 2023-01-11 17:19:21.913076: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:21.913997: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:22.051460: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:22.052304: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:22.053026: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:22.053729: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:22.055018: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-11 17:19:22.306814: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:22.307659: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:22.308445: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:22.309182: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:22.309937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:22.310670: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:25.193600: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:25.194464: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:25.195251: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:25.196084: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:25.196870: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:25.197595: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2023-01-11 17:19:25.200742: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:25.201410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# classification (Dense)       (None, 9)                 1161
# =================================================================
# Total params: 24,146,313
# Trainable params: 24,093,193
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
assert tf.test.is_gpu_available()
# Out:
# Num GPUs Available:  2
# 2023-01-11 17:19:27.951141: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:27.951856: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:27.952725: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:27.953213: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:27.954294: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:27.954838: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:27.955737: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:27.956438: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:27.957369: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:27.957775: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2023-01-11 17:19:27.957889: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-11 17:19:27.958834: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
EPOCHS = 15
checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint] 

history = model.fit(train_generator,validation_data =validation_generator, epochs=EPOCHS, callbacks=callbacks_list)
# Out:
# 2023-01-11 17:19:29.065051: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/15
# 2023-01-11 17:19:37.096868: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 196/196 [==============================] - 259s 1s/step - loss: 0.9218 - acc: 0.6931 - val_loss: 3.0515 - val_acc: 0.1108
#
# Epoch 00001: val_loss improved from inf to 3.05154, saving model to model_weights.h5
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/15
# 196/196 [==============================] - 220s 1s/step - loss: 0.4126 - acc: 0.8672 - val_loss: 2.3883 - val_acc: 0.1012
#
# Epoch 00002: val_loss improved from 3.05154 to 2.38830, saving model to model_weights.h5
# Epoch 3/15
# 196/196 [==============================] - 215s 1s/step - loss: 0.3096 - acc: 0.9035 - val_loss: 2.0283 - val_acc: 0.2554
#
# Epoch 00003: val_loss improved from 2.38830 to 2.02828, saving model to model_weights.h5
# Epoch 4/15
# 196/196 [==============================] - 219s 1s/step - loss: 0.2783 - acc: 0.9083 - val_loss: 1.1110 - val_acc: 0.6402
#
# Epoch 00004: val_loss improved from 2.02828 to 1.11105, saving model to model_weights.h5
# Epoch 5/15
# 196/196 [==============================] - 219s 1s/step - loss: 0.2363 - acc: 0.9232 - val_loss: 0.3975 - val_acc: 0.8683
#
# Epoch 00005: val_loss improved from 1.11105 to 0.39755, saving model to model_weights.h5
# Epoch 6/15
# 196/196 [==============================] - 219s 1s/step - loss: 0.2173 - acc: 0.9321 - val_loss: 0.2068 - val_acc: 0.9341
#
# Epoch 00006: val_loss improved from 0.39755 to 0.20679, saving model to model_weights.h5
# Epoch 7/15
# 196/196 [==============================] - 219s 1s/step - loss: 0.1962 - acc: 0.9361 - val_loss: 0.1418 - val_acc: 0.9510
#
# Epoch 00007: val_loss improved from 0.20679 to 0.14183, saving model to model_weights.h5
# Epoch 8/15
# 196/196 [==============================] - 219s 1s/step - loss: 0.1698 - acc: 0.9443 - val_loss: 0.1639 - val_acc: 0.9382
#
# Epoch 00008: val_loss did not improve from 0.14183
# Epoch 9/15
# 196/196 [==============================] - 219s 1s/step - loss: 0.1542 - acc: 0.9504 - val_loss: 0.1555 - val_acc: 0.9518
#
# Epoch 00009: val_loss did not improve from 0.14183
# Epoch 10/15
# 196/196 [==============================] - 220s 1s/step - loss: 0.1544 - acc: 0.9498 - val_loss: 0.1784 - val_acc: 0.9365
#
# Epoch 00010: val_loss did not improve from 0.14183
# Epoch 11/15
# 196/196 [==============================] - 220s 1s/step - loss: 0.1406 - acc: 0.9517 - val_loss: 0.1071 - val_acc: 0.9639
#
# Epoch 00011: val_loss improved from 0.14183 to 0.10711, saving model to model_weights.h5
# Epoch 12/15
# 196/196 [==============================] - 219s 1s/step - loss: 0.1291 - acc: 0.9589 - val_loss: 0.1140 - val_acc: 0.9719
#
# Epoch 00012: val_loss did not improve from 0.10711
# Epoch 13/15
# 196/196 [==============================] - 218s 1s/step - loss: 0.1277 - acc: 0.9616 - val_loss: 0.1482 - val_acc: 0.9518
#
# Epoch 00013: val_loss did not improve from 0.10711
# Epoch 14/15
# 196/196 [==============================] - 218s 1s/step - loss: 0.1278 - acc: 0.9578 - val_loss: 0.1217 - val_acc: 0.9598
#
# Epoch 00014: val_loss did not improve from 0.10711
# Epoch 15/15
# 196/196 [==============================] - 217s 1s/step - loss: 0.1138 - acc: 0.9635 - val_loss: 0.1186 - val_acc: 0.9655
#
# Epoch 00015: val_loss did not improve from 0.10711

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label="train")
plt.plot(history.history['val_loss'], label="val")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(loc="best")
plt.show()

# %%
test_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_generator =  test_datagen.flow_from_directory( IMAGE_TEST_DIR,
                                                    shuffle=False,
                                                          batch_size  = 32,
                                                          class_mode  = None, 
                                                          target_size = (224, 224))
# Out:
# Found 2679 images belonging to 1 classes.

# %%
test_generator.reset()

# %%
model = tf.keras.models.load_model("/kaggle/working/model_weights.h5")
pred = model.predict_generator(test_generator)
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
print(pred.shape)
filenames=test_generator.filenames
print(len(filenames))
# Out:
# (2679, 9)
# 2679

# %%
res1 = list(map(lambda st: str.replace(st, "test/", ""), filenames))
res2 = list(map(lambda st: str.replace(st, ".jpg", ""), res1))

# %%
actual = train_generator.classes

# %%
import os
submission = pd.DataFrame()
submission["ID"] = res2
classes = ["Church","Enough/Satisfied","Friend","Love","Me","Mosque","Seat","Temple","You"]
for i, c in enumerate(classes):
    print(c)
    print(i)
    submission[c] = pred[:,i]
submission.head()
# Out:
# Church
# 0
# Enough/Satisfied
# 1
# Friend
# 2
# Love
# 3
# Me
# 4
# Mosque
# 5
# Seat
# 6
# Temple
# 7
# You
# 8
#                  ID        Church  Enough/Satisfied        Friend  \
# 0  ImageID_00AVE728  1.303288e-08      1.082116e-08  2.549148e-10
# 1  ImageID_00CB7YJ2  2.971056e-05      9.999651e-01  4.357933e-07
# 2  ImageID_00HEGX6X  3.291440e-02      4.260680e-02  1.120896e-01
# 3  ImageID_016X4GBI  2.451719e-03      5.282098e-04  3.639082e-06
# 4  ImageID_01ITRYRU  9.694299e-08      4.810381e-08  2.057146e-08
#
#            Love            Me        Mosque          Seat        Temple  \
# 0  1.034369e-09  6.164340e-11  3.484025e-11  1.998256e-10  1.000000e+00
# 1  9.155005e-09  1.748978e-08  2.948026e-06  4.967638e-08  1.732839e-06
# 2  2.027970e-01  3.727988e-01  1.248568e-01  7.248480e-02  2.451280e-02
# 3  1.168579e-05  1.130292e-06  9.970002e-01  1.887801e-06  9.686811e-07
# 4  2.920483e-08  2.615468e-08  2.455678e-07  9.999986e-01  2.251022e-08
#
#             You
# 0  8.200325e-11
# 1  7.990333e-09
# 2  1.493908e-02
# 3  5.309464e-07
# 4  9.389332e-07

# %%
submission.to_csv('sub15.csv',index=False)

# %%
submission.shape
# Out:
# (2679, 10)
